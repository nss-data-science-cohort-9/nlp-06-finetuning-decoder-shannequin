# %%
# !pip uninstall -y torchao
# !pip install torchao>=0.16.0 --no-cache-dir

# %% [markdown]
# ## Decoder Finetuning Example
#
# In this notebook, you'll get to practice fine-tuning a generative model.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import Trainer, TrainingArguments
import torch
from torch.utils.data import Dataset
from peft import get_peft_model, LoraConfig, TaskType
# Out:
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so

# %% [markdown]
# For this example, we'll be working with the script of the first episode of Star Trek, the Next Generation.
#
# First, we'll read it in and do some minor cleanup.

# %%
with open("script.txt", "r", encoding="utf-8") as f:
    text = f.read()

lines = [line.strip() for line in text.split('\n') if len(line.strip()) > 10]
text = "\n".join(lines)
print(text[:1000])
# Out:
# STAR TREK: THE NEXT GENERATION
# "Encounter at Farpoint"
# D.C. Fontana
# Gene Roddenberry
# This script is not for publicaion or reproduction.
# No one is authorized to dispose of the same. If los t or
# destroyed, please notify the Script Department.
# FINAL DRAFT
# April 13, 1987
# 1    EXT. SPACE - STARSHIP (OPTICAL)
# The U.S.S. Enterprise NCC 1701-D traveling at warp  speed
# through space.
# PICARD V.O.
# Captain's log, stardate 42353.7.
# Our destination is planet Cygnus
# IV, beyond which lies the great
# unexplored mass of the galaxy.
# 2    OTHER INTRODUCTORY ANGLES (OPTICAL)
# on the gigantic new Enterprise NCC 1701-D.
# PICARD V.O.
# My orders are to examine Farpoint,
# a starbase built there by the
# inhabitants of that world.
# Meanwhile ...
# 3    INT. ENGINE ROOM
# Huge, with a giant wall diagram showing the immens ity
# of this Galaxy Class starship.
# PICARD V.O.
# (continuing)
# ... I am becoming better
# acquainted with my new command,
# this Galaxy Class U.S.S.
# Enterprise.
# 4    CLOSER ON VESSEL DIAGRAM
# Showing the details an

# %% [markdown]
# First, we need to create our tokenizer.
#
# **Part 1:** Create a tokenizer using "distilgpt2" with the [Autotokenizer.from_pretrained method](https://huggingface.co/docs/transformers/v4.52.3/en/model_doc/auto#transformers.AutoTokenizer).

# %%
tokenizer = AutoTokenizer.from_pretrained('distilgpt2')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# During training, all sequences need to be the same lenght, so we need to set a padding token for shorter sequences. We'll use the end of sequence token for this.

# %%
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# **Part 2:** Use the [encode method](https://huggingface.co/docs/transformers/en/main_classes/tokenizer#transformers.PreTrainedTokenizer.encode) to encode the text. Make sure that this returns PyTorch tensors. Save

# %%
tokens = tokenizer.encode(text, return_tensors="pt")
# Out:
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (33069 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# Now, we'll split the text into shorter chunks.

# %%
tokens = tokens[0]

chunk_size = 128
chunks = [tokens[i:i+chunk_size] for i in range(0, len(tokens)-chunk_size, chunk_size)]

input_ids = torch.stack([torch.tensor(chunk) for chunk in chunks])
# Out:
# /tmp/ipykernel_37325/3206389813.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_ids = torch.stack([torch.tensor(chunk) for chunk in chunks])

# %% [markdown]
# Here's a helper class for our training data.

# %%
class ScriptDataset(Dataset):
    def __init__(self, input_ids):
        self.input_ids = input_ids

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": torch.ones_like(self.input_ids[idx]),
            "labels": self.input_ids[idx],
        }

dataset = ScriptDataset(input_ids)

# %% [markdown]
# **Part 3:** Make a model named base_model by using the [AutoModelforCausalLM.from_pretrained method](https://huggingface.co/docs/transformers/en/model_doc/auto#transformers.AutoModelForCausalLM), using the pretrained distilgpt2 model.

# %%
base_model = AutoModelForCausalLM.from_pretrained('distilgpt2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]

# %%
# Match the token_embeddings to the same for the tokenizer.
base_model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(50257, 768)

# %% [markdown]
# **Part 4:** We'll be finetuning our model using LoRA. Set up a LoraConfig object, lora_config, with rank 8, alpha of 32 and dropout of 0.1. Set the target_modules to ["c_attn"], the bias to "none", and the task_type to TaskType.CAUSAL_LM.
#
# Then, use the [get_peft_model function](https://huggingface.co/docs/peft/v0.15.0/en/package_reference/peft_model#peft.get_peft_model) to create a model using the config object. Save the results to an object named model.

# %%
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    lora_dropout=0.1,
    target_modules=["c_attn"],
    bias="none",
    task_type=TaskType.CAUSAL_LM
)

model = get_peft_model(base_model, lora_config)
# Out:
# /usr/local/lib/python3.12/dist-packages/peft/tuners/lora/layer.py:2504: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %% [markdown]
# We'll set up a Trainer object and call the train method.

# %%
training_args = TrainingArguments(
    output_dir="./xfiles_distilgpt2_lora",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    logging_steps=10,
    save_steps=50,
    warmup_steps=5,
    learning_rate=2e-4,
    save_total_limit=1,
    fp16=True,
    report_to="none",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    processing_class=tokenizer
)

trainer.train()
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 50256}.
# [transformers] `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='387' max='387' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [387/387 00:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.712453</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>4.770882</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>4.723295</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>4.743188</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>4.815984</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>4.729205</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>4.690752</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>4.627505</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>4.526951</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>4.542201</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>4.498171</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>4.455153</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>4.275291</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>4.413734</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>4.374889</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>4.486349</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>4.486365</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>4.546598</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>4.279393</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.355501</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>4.252328</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>4.326545</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>4.298104</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>4.290231</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>4.385173</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>4.298056</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>4.412240</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>4.371769</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>4.311240</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>4.369290</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>4.308702</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>4.190836</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>4.079935</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>4.382787</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>4.245390</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>4.480813</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>4.294390</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>4.252002</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=387, training_loss=4.4334963027204966, metrics={'train_runtime': 20.9809, 'train_samples_per_second': 36.891, 'train_steps_per_second': 18.445, 'total_flos': 25368113184768.0, 'train_loss': 4.4334963027204966, 'epoch': 3.0})

# %% [markdown]
# Before generating new text, let's ensure that we're using GPUs.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPT2LMHeadModel(
#       (transformer): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-5): 6 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2Attention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#       (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#     )
#   )
# )

# %% [markdown]
# Here's a helper function to generate new text, given a model.

# %%
def generate_text(model, prompt, tokenizer, device, max_new_tokens=100):
    model.eval()    # Ensures that we're generating, not training
    inputs = tokenizer(prompt, return_tensors="pt", padding=True).to(device)  # Tokenize the prompt
    output = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=0.9,
        temperature=1.0,
        pad_token_id=tokenizer.eos_token_id
    )
    return tokenizer.decode(output[0], skip_special_tokens=True)  # The model generates tokens, so we need to decode those back to words

# %% [markdown]
# We'll load back in the base pretrained model for comparison.

# %%
base_model = AutoModelForCausalLM.from_pretrained("distilgpt2").to(device)
tokenizer = AutoTokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]

# %% [markdown]
# **Part 5:** Using the generate_text function, try out the prompt "PICARD" with both the pretrained distilgpt2 model (base_model), and the finetuned model. Try other prompts, too.

# %%
generate_text(base_model, "PICARD", tokenizer, device)
# Out:
# 'PICARD: The world is now a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and it\u202dis a new world, and'

# %%
generate_text(model, "PICARD", tokenizer, device)
# Out:
# "PICARD,‽\n‿ VOYER‽\n(SOUNDBITE OF BROADFINDING STARS)\n(SOUNDBITE OF CROSSING STAR S)\nPicard, as we see her looking at the ship and her crew with the utmost suspicion.\n‿ VOYER, you're in the\nsensitized room, captain.\n(VOYER, EXT. BAN FINDING STARS)\n(SOUNDBITE"

# %% [markdown]
# **Bonus:** See what happens if you allow more training epochs. You've also been provided all of the scripts from season 1. How does the model do when given more examples?

# %%
# Loop through files for files starting with "Star Trek", then read them to a variable called text
import os
text2 = ""
for filename in os.listdir("."):
    if filename.startswith("Star Trek"):
        with open(filename, "r", encoding="utf-8") as f:
            text2 += f.read()

# %%
len(text2)
# Out:
# 1812321

# %%
tokenizer2 = AutoTokenizer.from_pretrained('distilgpt2')

# %%
tokenizer2.pad_token = tokenizer2.eos_token

# %%
tokens2 = tokenizer2.encode(text, return_tensors="pt")
# Out:
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (33069 > 1024). Running this sequence through the model will result in indexing errors

# %%
tokens2 = tokens2[0]

chunk_size = 128
chunks2 = [tokens2[i:i+chunk_size] for i in range(0, len(tokens2)-chunk_size, chunk_size)]

input_ids2 = torch.stack([torch.tensor(chunk) for chunk in chunks2])
# Out:
# /tmp/ipykernel_37325/2589123809.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_ids2 = torch.stack([torch.tensor(chunk) for chunk in chunks2])

# %%
class ScriptDataset(Dataset):
    def __init__(self, input_ids):
        self.input_ids = input_ids

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": torch.ones_like(self.input_ids[idx]),
            "labels": self.input_ids[idx],
        }

dataset2 = ScriptDataset(input_ids2)

# %%
base_model2 = AutoModelForCausalLM.from_pretrained('distilgpt2')
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]

# %%
# Match the token_embeddings to the same for the tokenizer.
base_model2.resize_token_embeddings(len(tokenizer2))
# Out:
# Embedding(50257, 768)

# %%
lora_config2 = LoraConfig(
    r=8,
    lora_alpha=32,
    lora_dropout=0.1,
    target_modules=["c_attn"],
    bias="none",
    task_type=TaskType.CAUSAL_LM
)

model2 = get_peft_model(base_model2, lora_config2)
# Out:
# /usr/local/lib/python3.12/dist-packages/peft/tuners/lora/layer.py:2504: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %%
training_args2 = TrainingArguments(
    output_dir="./xfiles_distilgpt2_lora",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    logging_steps=10,
    save_steps=50,
    warmup_steps=5,
    learning_rate=2e-4,
    save_total_limit=1,
    fp16=True,
    report_to="none",
)

trainer2 = Trainer(
    model=model2,
    args=training_args2,
    train_dataset=dataset2,
    processing_class=tokenizer2
)

trainer2.train()
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 50256}.
#     <div>
#
#       <progress value='387' max='387' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [387/387 00:11, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.712579</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>4.770426</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>4.722511</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>4.740708</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>4.811456</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>4.726873</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>4.687220</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>4.627425</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>4.527449</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>4.545570</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>4.499288</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>4.454393</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>4.278060</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>4.415476</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>4.379855</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>4.486720</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>4.489556</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>4.552243</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>4.286042</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.361881</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>4.260832</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>4.332000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>4.303590</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>4.295969</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>4.392280</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>4.301802</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>4.421214</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>4.382025</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>4.315326</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>4.377747</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>4.315372</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>4.199992</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>4.089557</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>4.388925</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>4.252216</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>4.487982</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>4.303719</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>4.260482</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=387, training_loss=4.4375662397044575, metrics={'train_runtime': 11.8379, 'train_samples_per_second': 65.383, 'train_steps_per_second': 32.692, 'total_flos': 25368113184768.0, 'train_loss': 4.4375662397044575, 'epoch': 3.0})

# %%
device2 = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model2.to(device2)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPT2LMHeadModel(
#       (transformer): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-5): 6 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2Attention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#       (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#     )
#   )
# )

# %%
def generate_text(model, prompt, tokenizer, device, max_new_tokens=100):
    model.eval()    # Ensures that we're generating, not training
    inputs = tokenizer(prompt, return_tensors="pt", padding=True).to(device)  # Tokenize the prompt
    output = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=0.9,
        temperature=1.0,
        pad_token_id=tokenizer.eos_token_id
    )
    return tokenizer.decode(output[0], skip_special_tokens=True)  # The model generates tokens, so we need to decode those back to words

# %%
generate_text(model, "PICARD", tokenizer, device)
# Out:
# "PICARD: I've got this right here.\nWe've got some people on the floor, a couple of women and a man sitting with a face down with a smile on his face. He stares at me in disbelief.\nYou know, this is one of those things I would call out.\nThey are.\nYou know, we were two of those people.\nThe other guy sitting on the floor,\n(shitting)\nHe looks, he's a young man, right?"
